# %% [markdown]
# ## labeling_instructions
#
# This notebook presents examples of correct landmark labeling in a rat. Use the following table of contents to navigate quickly to your marker of choice. Make sure to look at the "quickstart" reference images below the table of contents as well.
#
# [HeadR](#HeadR). The right corner of the head mount/cap.
#
# [HeadB](#HeadB). The back/bottom corner of the head mount/cap.
#
# [HeadL](#HeadL). The left corner of the head moint/cap.
#
# [SpineF](#SpineF). The front of the spine (anterior thoracic), between the left and ride shoulders.
#
# [SpineM](#SpineM). The middle of the spine (anterior lumbar / posterior thoracic).
#
# [SpineB](#SpineB). The back/bottom of the spine (sacral), beetween the two hips.
#
# [Offset1](#Offset1). To the left of the spine, between the anterior/posterior positions of SpineF and SpineM.
#
# [Offset2](#Offset2). To the left of the spine, between the anterior/posterior positions of SpineM and SpineL.
#
# [HipL](#HipL). Top of the left leg. Posterior to SpineL.
#
# [HipR](#HipR). Top of the right leg. Posterior to SpineL.
#
# [ElbowL](#ElbowL). Left elbow. At the middle of the left arm (forelimb).
#
# [ArmL](#ArmL). Left forearm (forelimb).
#
# [ShoulderL](#ShoulderL). Left Shoulder. To the left of SpineF.
#
# [ShoulderR](#ShoulderR). Right Shoulder. To the right of SpineF.
#
# [ElbowR](#ElbowR). Right elbow. At the middle of the right arm (forelimb).
#
# [ArmR](#ArmR). Right forearm (forelimb).
#
# [KneeR](#KneeR). Above the right knee. Anterior to HipR.
#
# [KneeL](#KneeL). Above the left knee. Anterior to HipL.
#
# [ShinL](#ShinL). On the lower end of the left leg (hindlimb).
#
# [ShinR](#ShinR). On the lower end of the right leg (hindlimb).
#
# Quickstart:
# ![title](results/calibrd4_50frames_cams356/example_sample388461_CameraS_quickstart.png)
# ![title](results/calibrd4_50frames_cams356/example_sample388461_CameraE_quickstart.png)

# %%
import os
# Format markdown for a folder of examples
dirname_ = './results/calibrd4_50frames_cams356/ex{}/'
for i in range(20):
    dirname = './results/calibrd4_50frames_cams356/ex{}/'.format(i+1)
    files = os.listdir(dirname)
    thisstr = ""
    for j in range(len(files)):
        thisstr = thisstr + "![title]({})\n[Back Up](#labeling_instructions)\n".format(dirname.split('./')[1] + \
                                                                                    files[j])
    print('ex' + str(i+1))
    print(thisstr)
# Out:
# ex1
# ![title](results/calibrd4_50frames_cams356/ex1/example_sample388461_CameraE.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex1/example_sample503881_CameraE.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex1/example_sample233961_CameraE.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex1/example_sample388461_CameraU2.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex1/example_sample326861_CameraE.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex1/example_sample388461_CameraS.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex1/example_sample326861_CameraU2.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex1/example_sample171361_CameraE.png)
# [Back Up](#labeling_instructions)
# ...

# %% [markdown]
# ## HeadR
# ![title](results/calibrd4_50frames_cams356/ex1/example_sample388461_CameraE.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex1/example_sample503881_CameraE.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex1/example_sample233961_CameraE.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex1/example_sample388461_CameraU2.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex1/example_sample326861_CameraE.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex1/example_sample388461_CameraS.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex1/example_sample326861_CameraU2.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex1/example_sample171361_CameraE.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex1/example_sample233961_CameraU2.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex1/example_sample267811_CameraS.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex1/example_sample233961_CameraS.png)
# [Back Up](#labeling_instructions)

# %% [markdown]
# ## HeadB
# ![title](results/calibrd4_50frames_cams356/ex2/example_sample318691_CameraU2.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex2/example_sample388461_CameraE.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex2/example_sample503881_CameraE.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex2/example_sample233961_CameraE.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex2/example_sample388461_CameraU2.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex2/example_sample388461_CameraS.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex2/example_sample326861_CameraU2.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex2/example_sample171361_CameraE.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex2/example_sample233961_CameraU2.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex2/example_sample267811_CameraS.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex2/example_sample233961_CameraS.png)
# [Back Up](#labeling_instructions)

# %% [markdown]
# ## HeadL
# ![title](results/calibrd4_50frames_cams356/ex3/example_sample326861_CameraS.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex3/example_sample388461_CameraE.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex3/example_sample267811_CameraE.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex3/example_sample171361_CameraU2.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex3/example_sample233961_CameraE.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex3/example_sample487621_CameraU2.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex3/example_sample388461_CameraU2.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex3/example_sample388461_CameraS.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex3/example_sample326861_CameraU2.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex3/example_sample487621_CameraS.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex3/example_sample171361_CameraE.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex3/example_sample233961_CameraS.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex3/example_sample267811_CameraU2.png)
# [Back Up](#labeling_instructions)

# %% [markdown]
# ## SpineF
# ![title](results/calibrd4_50frames_cams356/ex4/example_sample318691_CameraU2.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex4/example_sample503881_CameraS.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex4/example_sample388461_CameraE.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex4/example_sample267811_CameraE.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex4/example_sample171361_CameraU2.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex4/example_sample233961_CameraE.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex4/example_sample487621_CameraU2.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex4/example_sample388461_CameraU2.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex4/example_sample388461_CameraS.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex4/example_sample97331_CameraS.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex4/example_sample326861_CameraU2.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex4/example_sample487621_CameraS.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex4/example_sample487621_CameraE.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex4/example_sample267811_CameraS.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex4/example_sample233961_CameraS.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex4/example_sample267811_CameraU2.png)
# [Back Up](#labeling_instructions)

# %% [markdown]
# ## SpineM
# ![title](results/calibrd4_50frames_cams356/ex5/example_sample318691_CameraU2.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex5/example_sample503881_CameraS.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex5/example_sample388461_CameraE.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex5/example_sample171361_CameraU2.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex5/example_sample233961_CameraE.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex5/example_sample487621_CameraU2.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex5/example_sample388461_CameraU2.png)
# [Back Up](#labeling_instructions)
# ![title](results/calibrd4_50frames_cams356/ex5/example_s